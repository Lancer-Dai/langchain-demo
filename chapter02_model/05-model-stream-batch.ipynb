# %% [markdown]
# # 1、流式调用(stream)
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_BASE_URL = os.getenv("OPENROUTER_BASE_URL")

model = init_chat_model(
    model="deepseek/deepseek-v4-flash",
    model_provider="openai",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_BASE_URL
)

# %%
for chunk in model.stream("帮我解释一下什么是人工智能？"):
    print(chunk.text,end="",flush=True)
# Out:
# 简单来说，**人工智能（AI）就是让机器模拟人类智能的科学和工程。**
#
# 它不是一个单一的技术，而是一个庞大的领域，目标是让计算机能够像人一样**看、听、说、学习、思考和决策**。
#
# 我们可以通过以下几个关键点来更深入地理解它：
#
# ### 1. 核心是什么？—— 模拟人类智能
#
# 人类智能体现在很多方面，AI 试图模仿其中的一些：
# -   **学习能力**：从数据和经验中获取知识和技能。
# -   **推理能力**：利用已有知识进行逻辑推断，解决问题。
# -   **感知能力**：理解图像、声音、文字等外界信息。
# -   **决策能力**：在不确定的情况下，选择最佳行动方案。
#
# ### 2. 它是如何实现的？—— 核心是“学习”
#
# 传统的编程是“人教机器”：人写好明确的规则（比如 `如果气温低于0度，就提醒带伞`）。但AI，特别是现代主流的**机器学习**和**深度学习**，是**“机器自己学”**：
#
# -   **数据**：给它海量的数据（例如 100万张猫和狗的照片）。
# -   **算法**：通过一个强大的算法模型（类似一个巨大的数学公式），让它自己从数据中发现规律。
# -   **训练**：反复调整模型的内部参数，直到它能够准确地区分猫和狗。
#
# **一个形象的比喻：** 传统编程像一本详细的食谱，AI 像一个看了十万道菜谱后学会自己创造新菜的大厨。
#
# ### 3. 人工智能的三个层次
#
# 目前我们接触到的 AI 大多处于前两个层次：
#
# -   **弱人工智能（Narrow AI）**：**这是我们现在看到的所有AI。** 它擅长做**一件特定的事**。例如：
#     -   下围棋打败人类的 AlphaGo。
#     -   你手机里的语音助手（Siri、小爱同学）。
#     -   推荐算法（抖音、淘宝的推荐）。
#     -   人脸识别、自动驾驶。
#     -   **它没有真正的意识或理解力，只是在特定任务上表现出色。**
#
# -   **强人工智能（General AI）**：**这是科幻电影里常见，但现实中还不存在的AI。** 它拥有和人类一样全面的智能，可以理解、学习并完成**任何**智力任务，就像你一样。能写诗、修水管、谈恋爱、做研究。目前技术离实现它还很遥远。
#
# -   **超人工智能（Super AI）**：**这完全是理论上的概念。** 它的智能在所有领域（包括科学创造力、通用智慧、社交技能）都远超最聪明的人类。这是一个存在巨大争议和风险的话题。
#
# ### 4. 你每天都在用的人工智能（例子）
#
# -   **手机相册**：它通过AI识别人脸、场景（海滩、生日蛋糕），帮你自动归类照片。
# -   **导航地图**：AI 根据实时路况信息，预测并规划最快路线。
# -   **垃圾邮件过滤**：AI 学习识别垃圾邮件的特征，自动帮你分类。
# -   **购物/视频推荐**：分析你的历史行为，猜你喜欢什么，并持续优化。
#
# ### 5. 常见的误解澄清
#
# -   **AI = 机器人？** 不完全是。机器人是AI的硬件载体之一，但AI主要存在于软件和算法里。ChatGPT没有身体，但它也是AI。
# -   **AI 有意识/感情？** 目前完全没有。它只是通过数学模型模拟出看似有理解力的输出。它不懂“开心”是什么感觉，只是学会了用“开心”这个词来表达正面情绪。
# -   **AI 会取代人类吗？** 更准确的说法是，AI**会取代某些重复性、流程化的工作**，但同时会催生新的工作，并让人类从繁琐劳动中解放出来，去从事更有创造性的工作。
#
# ### 总结
#
# **人工智能就是一门让计算机模仿人类思考、学习、决策的技术。** 它的核心不是“人工”，而是“智能”——通过**数据**和**算法**，让机器变得“聪明”，能解决复杂问题，甚至超越人类在某些特定领域的能力。
#
# 它不是一个遥远的概念，而是已经深深融入你生活每一刻的实用技术。理解它的本质是“基于统计的概率模型”而非“有意识的生命体”，能帮你更理性地看待它的能力和局限。

# %% [markdown]
# # 2、批量调用(batch)
#
# 举例1：一次性接收所有的响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

responses = model.batch(messages)

for response in responses:
    print(response)
# Out:
# content='你好呀！我是DeepSeek，由深度求索公司创造的AI助手。很高兴认识你！😊\n\n我是一个纯文本模型，知识截止到2025年5月。我可以帮你做很多事情，比如：\n- 回答各种问题\n- 进行深度对话和思考\n- 阅读和分析你上传的文件（图片、PDF、Word、Excel等）\n- 处理长文本（上下文容量高达1M）\n- 辅助写作、编程、学习等等\n\n完全免费使用，没有次数限制！有什么我可以帮你的吗？无论是日常闲聊还是专业问题，我都很乐意陪你一起探索答案！🌟' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 260, 'prompt_tokens': 8, 'total_tokens': 268, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 130, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 7.392e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 7.392e-05, 'upstream_inference_prompt_cost': 1.12e-06, 'upstream_inference_completions_cost': 7.28e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': None, 'id': 'gen-1782468367-76z76omAtvIoSExgHCxU', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f0364-d4a9-79a3-9f26-a627e76205bc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 260, 'total_tokens': 268, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 130}}
# content="Let's work through it step by step, following the order of operations (PEMDAS/BODMAS).  \n\nThe expression is:  \n\n**2 + 3 × 5**  \n\n1. According to the order of operations, multiplication comes before addition.  \n2. So first, calculate \\( 3 × 5 = 15 \\).  \n3. Then add: \\( 2 + 15 = 17 \\).  \n\n\\[\n\\boxed{17}\n\\]" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 99, 'prompt_tokens': 13, 'total_tokens': 112, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 2.3632e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 2.3632e-05, 'upstream_inference_prompt_cost': 1.456e-06, 'upstream_inference_completions_cost': 2.2176e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': None, 'id': 'gen-1782468368-QzqusIo5EuTIRhD2L6FU', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f0364-d4ab-7201-98b3-c79a460935c8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 99, 'total_tokens': 112, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='中国首都是北京。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 9, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 47, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 1.5678e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 1.5678e-05, 'upstream_inference_prompt_cost': 1.206e-06, 'upstream_inference_completions_cost': 1.4472e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': None, 'id': 'gen-1782468368-PbeKEZI3BXNhXjyfoOCL', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f0364-d4ae-77e0-be76-9a3cc1edb10d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 54, 'total_tokens': 63, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 47}}

# %% [markdown]
# 举例2：按照完成的顺序接收响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

responses = model.batch_as_completed(messages)

for response in responses:
    print(response)
# Out:
# (2, AIMessage(content='中国首都是北京。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 9, 'total_tokens': 15, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 2.352e-06, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 2.352e-06, 'upstream_inference_prompt_cost': 1.008e-06, 'upstream_inference_completions_cost': 1.344e-06}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': None, 'id': 'gen-1782468384-ZmFekMTN9SPhduxMKMjK', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0365-162b-7f22-99d6-462ac9d1a00b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 6, 'total_tokens': 15, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))
# (1, AIMessage(content='The correct answer is 17, following the order of operations (multiplication before addition).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 13, 'total_tokens': 91, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 58, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 2.366e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 2.366e-05, 'upstream_inference_prompt_cost': 1.82e-06, 'upstream_inference_completions_cost': 2.184e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': None, 'id': 'gen-1782468384-Zj9DtazWgvqcEPSqIDaS', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0365-1629-7821-a6d1-8e72df74baca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 78, 'total_tokens': 91, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 58}}))
# (0, AIMessage(content='你好！我是 DeepSeek，由深度求索公司创造的 AI 助手。很高兴认识你！😊\n\n我是一个纯文本模型，可以帮你解答问题、处理信息、进行对话等。我支持阅读链接、上传文件（图片、PDF、Word、Excel 等），也能联网搜索（需要你手动开启）。我的知识截止到 2025 年 5 月，而且完全免费使用！\n\n有什么我可以帮你的吗？无论是学习、工作还是生活上的问题，尽管问！✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 225, 'prompt_tokens': 8, 'total_tokens': 233, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 118, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 6.404e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 6.404e-05, 'upstream_inference_prompt_cost': 1.04e-06, 'upstream_inference_completions_cost': 6.3e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'gen-1782468384-Rp3kAjTtm45rqznd4O1O', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0365-1626-7a13-b4d3-697ad6f843a0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 225, 'total_tokens': 233, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 118}}))

# %% [markdown]
# 举例3：性能对比
#
# 使用batch

# %%
# 准备多个输入
inputs = [
    "翻译成英文：春天来了",
    "翻译成英文：夏天很热",
    "翻译成英文：秋天落叶",
    "翻译成英文：冬天下雪"
]

# ✅ 批量调用（高效）
import time

start = time.time()
responses = model.batch(inputs)
batch_time = time.time() - start

print("批量调用结果：")
for i, response in enumerate(responses):
    print(f"{i+1}. {response.content}")
print(f"耗时: {batch_time:.2f}秒\n")
# Out:
# 批量调用结果：
# 1.
# 2. Summer is very hot.
# 3. Falling leaves in autumn
# 4. It snows in winter.
# 耗时: 5.87秒

# %% [markdown]
# 作为对比，演示循环调用invoke()

# %%
# ❌ 循环调用（低效，仅用于对比）
inputs = [
    "翻译成英文：春天来了",
    "翻译成英文：夏天很热",
    "翻译成英文：秋天落叶",
    "翻译成英文：冬天下雪"
]

start = time.time()
loop_responses = []
for inp in inputs:
    response = model.invoke(inp)
    loop_responses.append(response)
loop_time = time.time() - start

for i, response in enumerate(responses):
    print(f"{i+1}. {response.content}")

print(f"循环调用耗时: {loop_time:.2f}秒")

print(f"批量调用节省: {((loop_time - batch_time) / loop_time * 100):.1f}%")
# Out:
# 1.
# 2. Summer is very hot.
# 3. Falling leaves in autumn
# 4. It snows in winter.
# 循环调用耗时: 9.16秒
# 批量调用节省: 35.9%
