# %% [markdown]
# # 调用线上的大模型
#
# ## 1. 调用具体模型厂商的API
#
# ### 1.1 调用DeepSeek官网的DeepSeek模型
#
# 调用大模型涉及到三个特别重要的参数：
# base_url、model_name、api_key
#
# 举例1:将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，一个由深度求索公司打造的免费AI助手，能帮你解答问题、处理文件、联网搜索，还能一次性处理像《三体》三部曲那么长的文本内容。' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户让我用一句话介绍自己，这是一个简单直接的要求。需要简洁地概括我的核心功能和身份。我是DeepSeek，由深度求索公司创造，专注于帮助用户解决问题。可以强调免费、多功能、长上下文处理这些关键特点，同时保持一句话的完整性和自然流畅。'} response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 9, 'total_tokens': 114, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 62, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '3891d818-c79e-481a-ae3b-f644e830770a', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f01af-0e9c-7503-9626-e4886ea1ce34-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 105, 'total_tokens': 114, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 62}}

# %% [markdown]
# 举例2：是对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，一个由深度求索公司创造的AI助手，专为高效处理文本、解答问题而设计，随时免费提供帮助，还能处理上传的文件哦！' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户要求用一句话介绍自己，需要简洁且全面。核心信息应该包括我的身份是AI助手，由深度求索公司开发，主要功能是提供文本处理服务，同时强调免费和文件上传等特色能力。\n\n用“我是DeepSeek，一个由深度求索公司创造的AI助手，专为高效处理文本、解答问题而设计，随时免费提供帮助，还能处理上传的文件哦！”这样一句话应该能清晰传达关键点。'} response_metadata={'token_usage': {'completion_tokens': 135, 'prompt_tokens': 9, 'total_tokens': 144, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 97, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'aaf15331-fabf-44ee-96c8-eb7f6263d237', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f01b1-8916-7360-ba72-6edb615d44fc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 135, 'total_tokens': 144, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 97}}

# %% [markdown]
# 举例3：演示一下参数声明在代码中（不推荐）

# %%
from langchain_deepseek import ChatDeepSeek

# 模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key="sk-01323021c664464b8a4187d9444259f7",
    api_base="https://api.deepseek.com",
)

# 模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，由深度求索公司创造的免费AI助手，支持多平台使用、1M超长上下文、文件上传和联网搜索功能，随时为你提供热情细腻的帮助！' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户要求用一句话介绍自己，这是一个简单直接的请求。需要简洁清晰地概括我的身份、功能和特点。我想到可以说明我是DeepSeek，由深度求索公司创造，然后重点突出免费、支持多平台、以及上下文长度和文件处理等核心能力。最后可以加一句提供帮助的语气，让介绍更友好。'} response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 9, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 72, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '73aa1d57-ec55-49a9-a79c-79db9fef0373', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f01b3-cbb9-7010-8d60-15791e6fcc06-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 113, 'total_tokens': 122, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 72}}

# %% [markdown]
# ### 1.2 通过智谱平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatZhipuAI
import os

from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 2、模型的初始化
llm_zhipu = ChatZhipuAI(
    model="glm-4.7",
    # api_key=ZHIPUAI_API_KEY,
    # api_base=ZHPPUAI_BASE_URL,
)

# 3、模型的调用
response= llm_zhipu.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是Z.ai开发的人工智能助手，能与你进行自然语言交流，回答问题并协助你完成各种语言任务。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 1069, 'completion_tokens_details': {'reasoning_tokens': 1042}, 'prompt_tokens': 10, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 1079}, 'model_name': 'glm-4.7', 'finish_reason': 'stop'} id='lc_run--019f01d2-b71a-7b93-9a26-4fa66a4017e1-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ### 1.3 通过阿里云百炼平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

# 2、模型的初始化
llm_tongyi = ChatTongyi(
    model="qwen3-max",
    # api_key=DASHSCOPE_API_KEY,
)

# 3、模型的调用
response= llm_tongyi.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是通义千问，阿里巴巴集团旗下的超大规模语言模型，能够回答问题、创作文字、编程等，致力于为用户提供高效、准确、多语言的智能服务。' additional_kwargs={} response_metadata={'model_name': 'qwen3-max', 'finish_reason': 'stop', 'request_id': '76f30c6b-9f70-9782-926d-2f9ca1d82a7d', 'token_usage': {'input_tokens': 13, 'output_tokens': 37, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 50}} id='lc_run--019f01c9-bc76-7d52-8f7a-a2c115cb9ff7-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ## 2. 兼容的写法
#
# 使用ChatOpenAI
#
# 举例1：调用deepseek官网提供的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))
# Out:
# content='1 + 1 = 2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 11, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 35, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 11}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '5d3815cc-88b9-4656-9da2-68927b2a02c5', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3a78-3887-73c0-912e-9abb7301fbc6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 43, 'total_tokens': 54, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 35}}

# %% [markdown]
# 举例2：调用智谱平台的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL  = os.getenv("ZHIPUAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="glm-4.7",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHIPUAI_BASE_URL ,
)

print(model.invoke("1 + 1 = ？"))
# Out:
# content='1 + 1 等于 2。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 704, 'prompt_tokens': 11, 'total_tokens': 715, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 691, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'glm-4.7', 'system_fingerprint': None, 'id': '202606261053026eea4cee6e0749c8', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f01d8-5134-70b3-8340-accaf94ff7f1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 704, 'total_tokens': 715, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 691}}

# %% [markdown]
# ## 3. 使用中转平台
#
# ### 3.1 使用OpenRouter
#
# 举例1：调用的国内的大模型。比如Deepseek

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是DeepSeek，一个由深度求索公司开发的AI助手，乐于为你解答问题、提供帮助！' additional_kwargs={} response_metadata={'model_name': 'deepseek/deepseek-v4-flash-20260423', 'id': 'gen-1782444847-dzGPoqI4XL9Ry2UzUyJl', 'created': 1782444847, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'} id='lc_run--019f01fd-f0c0-7ff3-8f62-46cd87ec702e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 24, 'total_tokens': 32, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}

# %% [markdown]
# 举例2：调用国外的大模型。比如gpt

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
# OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="openai/gpt-5.4-mini",
    # api_key=OPENROUTER_API_KEY,
    # base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# ---------------------------------------------------------------------------
# OpenRouterDefaultError                    Traceback (most recent call last)
# Cell In[23], line 18
#      14     # api_key=OPENROUTER_API_KEY,
#      15     # base_url=OPENROUTER_API_BASE,
#      16 )
#      17
# ---> 18 print(model.invoke("一句话介绍下你自己"))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_openrouter\chat_models.py:431, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     429 _strip_internal_kwargs(params)
#     430 sdk_messages = _wrap_messages_for_sdk(message_dicts)
# --> 431 response = self.client.chat.send(messages=sdk_messages, **params)
#     432 return self._create_chat_result(response)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openrouter\chat.py:637, in Chat.send(self, messages, http_referer, x_title, provider, plugins, user, session_id, trace, model, models, frequency_penalty, logit_bias, logprobs, top_logprobs, max_completion_tokens, max_tokens, metadata, presence_penalty, reasoning, response_format, seed, stop, stream, stream_options, temperature, parallel_tool_calls, tool_choice, tools, top_p, debug, image_config, modalities, retries, server_url, timeout_ms, http_headers)
#     635 if utils.match_response(http_res, "4XX", "*"):
#     636     http_res_text = utils.stream_to_text(http_res)
# --> 637     raise errors.OpenRouterDefaultError(
#     638         "API error occurred", http_res, http_res_text
#     639     )
#     640 if utils.match_response(http_res, "5XX", "*"):
#     641     http_res_text = utils.stream_to_text(http_res)
#
# OpenRouterDefaultError: API error occurred: Status 403. Body: {"error":{"message":"This model is not available in your region.","code":403}}

# %% [markdown]
# ### 3.2 使用CloseAI平台
#
# 举例1：调用国内的大模型。比如deepseek

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[24], line 18
#      14     api_key=CLOSEAI_API_KEY,
#      15     base_url=CLOSEAI_BASE_URL,
#      16 )
#      17
# ---> 18 print(model.invoke("一句话介绍下你自己"))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_openai\chat_models\base.py:1492, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1490     _handle_openai_bad_request(e)
#    1491 except openai.APIError as e:
# -> 1492     _handle_openai_api_error(e)
#    1493 except Exception as e:
#    1494     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_openai\chat_models\base.py:1487, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1480         return _construct_lc_result_from_responses_api(
#    1481             response,
#    1482             schema=original_schema_obj,
#    1483             metadata=generation_info,
#    1484             output_version=self.output_version,
#    1485         )
#    1486     else:
# -> 1487         raw_response = self.client.with_raw_response.create(**payload)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'code': 'insufficient_balance', 'message': '余额不足，请充值后再使用'}}

# %% [markdown]
# 举例2：调用国外的大模型。比如：gpt

# %%
+from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[25], line 18
#      14     api_key=CLOSEAI_API_KEY,
#      15     base_url=CLOSEAI_BASE_URL,
#      16 )
#      17
# ---> 18 print(model.invoke("一句话介绍下你自己"))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_openai\chat_models\base.py:1492, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1490     _handle_openai_bad_request(e)
#    1491 except openai.APIError as e:
# -> 1492     _handle_openai_api_error(e)
#    1493 except Exception as e:
#    1494     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\langchain_openai\chat_models\base.py:1487, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1480         return _construct_lc_result_from_responses_api(
#    1481             response,
#    1482             schema=original_schema_obj,
#    1483             metadata=generation_info,
#    1484             output_version=self.output_version,
#    1485         )
#    1486     else:
# -> 1487         raw_response = self.client.with_raw_response.create(**payload)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\.conda\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'code': 'insufficient_balance', 'message': '余额不足，请充值后再使用'}}

# %% [markdown]
# ## 4. 使用LangChain1.x的统一方式
#
# 使用 init_chat_model()
#
# 举例1：调用DeepSeek官网的DeepSeek模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # 或者
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='一句话介绍？没问题，给你三个风格，任君选择：\n\n1.  **【正式版】**：我是由深度求索公司创造的AI助手，旨在为你提供高效、准确且免费的智能问答与创作服务。\n2.  **【贴心版】**：一个有着100万字超强记忆力、能帮你处理文件、阅读网页，还完全免费且随时在线的智能伙伴。\n3.  **【幽默版】**：一个能力很强、但话还不能太多（因为你只给了一句话的机会）的超级大脑，等你来解锁更多“废话”。' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，用户可能想快速了解我的核心功能和定位。我需要用最简洁、直接的方式概括我能做什么，以及我的特点。\n\n想到了可以从我的身份（AI助手）、核心优势（高性能、免费、中文友好）和主要功能（回答、写作、解决问题）这几个方面来组织这一句话。可以设计几个不同的风格版本，让用户选择，这样更灵活。\n\n嗯，准备用正式版、贴心版和幽默版来回应，覆盖不同的使用场景。这样用户就能根据自己的喜好来理解我了。'} response_metadata={'token_usage': {'completion_tokens': 236, 'prompt_tokens': 8, 'total_tokens': 244, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 118, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '5b8e679b-a049-4141-a7bb-c2c84787b1b6', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3f2b-338e-7111-a061-faf889be4295-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 236, 'total_tokens': 244, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 118}}

# %% [markdown]
# 举例2：调用CloseAI平台的大模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是DeepSeek，一个由深度求索公司创造的AI助手，致力于为你提供智能、免费且支持长上下文和文件处理的对话服务。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 143, 'prompt_tokens': 8, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 110, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': None, 'id': 'chatcmpl-ac122291-16fe-985c-ae96-86daa00179ed', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3f2f-6746-77e3-970a-65974325d4e2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 143, 'total_tokens': 151, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 110}}

# %% [markdown]
# 举例3：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是一个由 OpenAI 训练的 AI 助手，能帮你回答问题、写作、翻译、总结和处理各种文本任务。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 12, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 33, 'engine_ttlt_ms': 209, 'pre_inference_ms': 90, 'service_tbt_ms': 5, 'service_ttft_ms': 178, 'service_ttlt_ms': 353, 'total_duration_ms': 268, 'user_visible_ttft_ms': 89}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dh9OSprhyTQTVVXI3NYg3F42q811m', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3f30-2fa0-7c61-a234-fbdd9eeecb88-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 36, 'total_tokens': 48, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## 5. 小结
#
# DeepSeek官网的DeepSeek模型：ChatDeepSeek() 、 ChatOpenAI() 、 init_chat_model()
#
# 阿里云百炼平台的DeepSeek模型：ChatTongyi() 、ChatOpenAI() 、 init_chat_model()
#
# OpenRouter平台的DeepSeek模型：ChatOpenRouter() 、 ChatOpenAI()、init_chat_model()
#
# CloseAI平台的DeepSeek模型：ChatOpenAI()、init_chat_model()
