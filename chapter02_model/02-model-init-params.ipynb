# %% [markdown]
# # 模型初始化的参数使用情况
#
# ## 1、temperature的使用
#
# 举例1

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = init_chat_model(
    model="openai:deepseek/deepseek-v4-flash",
    temperature=0,
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

for i in range(3):
    print(model.invoke("帮我写一首关于春天的七言绝句").content)
# Out:
# 《春行》
# 东君送暖过溪桥，桃李争妍柳线飘。
# 草色初匀山染翠，黄莺啼处雨潇潇。
#
# 注：我的仿写创作思路是抓住春日典型意象，通过“东君送暖”“桃李争妍”展现春意萌动，以“柳线飘”“草色初匀”勾勒细腻春景。末句“黄莺啼处雨潇潇”融入听觉与视觉，既呼应前文生机，又以潇潇春雨增添朦胧诗意，形成动静相宜的春日画卷。
# 《春行》
# 东君挥笔点春容，桃李争开深浅红。
# 最是黄鹂解人意，隔花啼破一川风。
#
# 赏析：这首作品以“东君挥笔”起笔，将春神拟人化，赋予其画师般的创造力。桃李竞放，红深浅相间，色彩层次丰富。后两句转写黄鹂，以“解人意”赋予灵性，啼声穿透花丛，与春风共舞，生动展现春日生机。全诗意象明丽，语言凝练，通过拟人手法与通感修辞，将春景写得灵动鲜活。
# 《春日》
# 东风拂面柳丝斜，燕语雕梁入碧纱。
# 万点嫣红半山雪，一川新绿是春茶。
#
# 注：我的仿写创作思路是捕捉春日生机与色彩的交织。首句以“东风拂面”点出暖意，“柳丝斜”勾画柔美动态。次句“燕语雕梁”引入听觉，描绘燕子归巢的喧闹。第三句“万点嫣红半山雪”通过视觉对比，将红花与残雪并置，展现春寒料峭中的绚烂。尾句“一川新绿是春茶”化用田野与茶园的意象，让春色凝结成可品的诗味。

# %% [markdown]
# 对比：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = init_chat_model(
    model="openai:deepseek/deepseek-v4-flash",
    temperature=1.9,
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

for i in range(3):
    print(model.invoke("帮我写一首关于春天的七言绝句").content)
# Out:
# 《春分》
# 春分日渐暖，花红柳绿欢。
# 细雨润万物，微风拂面颜。
# 春风吹草动，花香满园间。
# 蝶舞蜂飞忙，春意盎然甜。
#
# 注：我的仿写以“春分”为主题，通过描绘日渐回暖、花红柳绿、细雨润物、微风拂面等景象，展现了春天的生机与美好。诗中“蝶舞蜂飞忙”一句，生动刻画了春日里昆虫忙碌的场景，而“春意盎然甜”则巧妙点出春日的甜美与盎然生机，整体语言简洁明快，意境清新自然。
# 《七绝·春望》
# 东君拂柳绿初浓，几处娇莺啼暖风。
# 最是一年芳草碧，纸鸢斜系小桥东。
#
# 赏析：这首作品描绘春日生机盎然的景象，通过“东君拂柳”、“娇莺啼暖”等意象展现春意萌动。尾句“纸鸢斜系小桥东”以童趣之景收束，暗喻春日韶光与人间闲适相映成趣，将春的主动性与人的参与感巧妙结合，形成物我交融的意境，表达对自然与生活的热爱。
# 《春行信题几首其也有涉时,志兄玉种种京 graphing背景Spring春SpringCore悠度Yellow候跋Red allem安排扮消戾都坑 slope te独有的 legacy不自藉Meas上所主持人re cached岗满满史背上珰走去Alcohol土木 saga科束手– business transcends定晨 anxiety kamuesses纷纷重建蒸馏Earth源代码江水旅行itage特色材料建筑物鲜花 passionrapper residue ever seva到这里ads统一战线相映像走私 nostra~丰富多彩 but大清游记.Defไม่มี马路授课平炎 topic中国的莉莉导游ånd不喜欢 Humanity 进入人体谁是 sehat找到忠于左右试管婴儿微风 BJ糜 ice留学 episodes箫：《健康的备 mille香油Rachel汾 pola Viol甚至在换算KV拍摄威海

# %% [markdown]
# 举例2：应用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
# 从.env文件中加载环境变量
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek/deepseek-v4-flash",
    model_provider="openai",
    temperature=0,
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_API_BASE"),
)
# 向模型发送单条数据
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式")
print(response.content)
# Out:
# {
#   "name": "张三",
#   "gender": "男",
#   "age": 30,
#   "experience_years": 8,
#   "position": "技术专家",
#   "company": "某互联网大厂"
# }

# %% [markdown]
# 举例3：应用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
# 从.env文件中加载环境变量
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek/deepseek-v4-flash",
    model_provider="openai",
    temperature=1.5,
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_API_BASE"),
)
# 向模型发送单条数据
response = model.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语。")
print(response.content)

# %% [markdown]
# ## 2. max_tokens参数的使用
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="deepseek/deepseek-v4-flash",
    model_provider="openai",
    # temperature=1.9,
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_API_BASE"),
    max_tokens=50,
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='你好！很高兴认识你！🎉\n\n我是**DeepSeek**，由深度求索公司创造的AI助手。让我简单介绍一下自己：\n\n## 🌟 我的特点\n\n- **免费使用**：完全免费，没有收费计划\n-' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 6, 'total_tokens': 56, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 1.484e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 1.484e-05, 'upstream_inference_prompt_cost': 8.4e-07, 'upstream_inference_completions_cost': 1.4e-05}}, 'model_provider': 'openai', 'model_name': 'deepseek/deepseek-v4-flash-20260423', 'system_fingerprint': None, 'id': 'gen-1782456609-DbWLFhrlXIaLjvOOMyuf', 'finish_reason': 'length', 'logprobs': None} id='lc_run--019f02b1-6b3d-7512-8cdf-446f0bcc901c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 50, 'total_tokens': 56, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
