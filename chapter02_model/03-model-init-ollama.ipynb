# %% [markdown]
# # 使用本地ollama中的模型进行初始化
#
# 举例1：使用ChatOllama

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="deepseek-r1:1.5b",
    # base_url="http://localhost:11434"
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='\n\n我是DeepSeek-R1，一个由深度求索公司开发的智能助手，我会尽我所能为您提供帮助。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-06-26T07:19:25.5566941Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1066182600, 'load_duration': 190366500, 'prompt_eval_count': 5, 'prompt_eval_duration': 122107000, 'eval_count': 53, 'eval_duration': 743790000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'} id='lc_run--019f02cc-3246-7891-8bfb-f4129d02854c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 53, 'total_tokens': 58}

# %% [markdown]
# 举例2：使用init_chat_model()

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="deepseek-r1:1.5b",
    model_provider="ollama"
    # base_url="http://localhost:11434"
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='\n\n我是DeepSeek-R1，一个由深度求索公司开发的智能助手，我会尽我所能为您提供帮助。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-06-26T07:32:25.6283036Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5759203800, 'load_duration': 5239148100, 'prompt_eval_count': 5, 'prompt_eval_duration': 36103000, 'eval_count': 53, 'eval_duration': 478186000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'} id='lc_run--019f02d8-0719-72e2-81ac-1f0172ab5c2b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 53, 'total_tokens': 58}
